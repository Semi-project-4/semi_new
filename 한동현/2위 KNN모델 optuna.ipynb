# %% [markdown]
# # Library

# %%
# !pip install optuna
# Out:
# Requirement already satisfied: optuna in /usr/local/lib/python3.10/dist-packages (3.5.0)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (1.13.0)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.10/dist-packages (from optuna) (6.8.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optuna) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (23.2)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.23)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.66.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0.1)
# Requirement already satisfied: Mako in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (1.3.0)
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.5.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna) (3.0.2)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna) (2.1.3)

# %%
# Classification
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib
from matplotlib import rc
import statsmodels.api as sm
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')
from sklearn.model_selection import KFold, cross_val_score, train_test_split, StratifiedKFold
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier, VotingClassifier, StackingClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.dummy import DummyClassifier
from sklearn.impute import SimpleImputer
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix, roc_curve
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler, LabelEncoder, OrdinalEncoder, OneHotEncoder
from sklearn.compose import ColumnTransformer
from xgboost import XGBClassifier
import optuna
from sklearn.ensemble import HistGradientBoostingClassifier
from sklearn.metrics import f1_score
from optuna.integration import OptunaSearchCV

# %% [markdown]
# # Data

# %%
'''1.데이터 가져오기/데이터 파일 로드'''


# Google Drive 파일 로드를 위한 Google Drive 마운트
from google.colab import drive

drive.mount('/content/drive')


# csv 파일 읽기
def r_csv(*file_names):
    path = '/content/drive/MyDrive/Colab Notebooks/data/'
    data_list = []
    for file_name in file_names:
        data = pd.read_csv(path + file_name, encoding='EUC-KR')
        data_list.append(data)
    return data_list

# csv 파일 읽기
origin_train_data, origin_test_data, origin_sample_submission = r_csv('train.csv', 'test.csv', 'sample_submission.csv')

# 원본 보존을 위해 카피해서 사용
train, test, ss = origin_train_data.copy(), origin_test_data.copy(), origin_sample_submission.copy()

train.drop(['user_id'], axis=1, inplace=True)
test.drop(['user_id'], axis=1, inplace=True)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Preprocessing

# %%
#단계별로 인코딩
train['preferred_difficulty_level'] = train['preferred_difficulty_level'].map({'Low':0, 'Medium':1,'High':2})
test['preferred_difficulty_level'] = test['preferred_difficulty_level'].map({'Low':0, 'Medium':1,'High':2})

#일반은 0, 프리미엄은 1로 인코딩
train['subscription_type'] = train['subscription_type'].map({'Basic':0, 'Premium':1})
test['subscription_type'] = test['subscription_type'].map({'Basic':0, 'Premium':1})

# %% [markdown]
# # Feature Engineering

# %%
def fe(df):
    # 평균 로그인 시간 / 가입 기간
    df['login_duration_ratio'] = df['average_login_time'] / (df['subscription_duration'] * 30)

    # 완료한 코스 수 대비 가입 기간
    df['course_duration_ratio'] = df['total_completed_courses'] / (df['subscription_duration'] * 30)

    # 평균 학습 시간 대비 활동적인 학습 일수
    df['learning_time_active_days_ratio'] = df['average_time_per_learning_session'] / df['monthly_active_learning_days']

    # 고객 문의 이력 대비 가입 기간
    df['inquiry_to_duration_ratio'] = df['customer_inquiry_history'] / (df['subscription_duration'] * 30)

    # 가입 기간 대비 중단된 학습 세션 수
    df['abandoned_sessions_to_duration_ratio'] = df['abandoned_learning_sessions'] / (df['subscription_duration']* 30)

    # 월별 이용 시간
    df['monthly_login_time'] = df['average_login_time'] * df['monthly_active_learning_days']

    # 평균 로그인 시간 대비 커뮤니티 레벨
    df['community_login_ratio'] = df['community_engagement_level'] / df['average_login_time']

    # 평균 로그인 시간 대비 완료한 코스 수
    df['login_to_course_ratio'] = df['total_completed_courses'] / df['average_login_time']

    return df


train = fe(train)
test = fe(test)

# %% [markdown]
# # Modeling

# %%
X = train.drop(['target', 'customer_inquiry_history', 'preferred_difficulty_level'], axis=1)
# -> 0.523
y = train['target']

# %%
X.columns
# Out:
# Index(['subscription_duration', 'recent_login_time', 'average_login_time',
#        'average_time_per_learning_session', 'monthly_active_learning_days',
#        'total_completed_courses', 'recent_learning_achievement',
#        'abandoned_learning_sessions', 'community_engagement_level',
#        'subscription_type', 'payment_pattern', 'login_duration_ratio',
#        'course_duration_ratio', 'learning_time_active_days_ratio',
#        'inquiry_to_duration_ratio', 'abandoned_sessions_to_duration_ratio',
#        'monthly_login_time', 'community_login_ratio', 'login_to_course_ratio'],
#       dtype='object')

# %%
# KNN 학습 모델
score_list = []
def knn_objective(trial):

    param_grid = {
        'n_neighbors': trial.suggest_int('n_neighbors', 1, 50),
        'weights': trial.suggest_categorical('weights', ['uniform', 'distance']),
        'metric': trial.suggest_categorical('metric',['euclidean', 'manhattan']),
        'p': trial.suggest_int('p', 1, 5)
    }

    model = KNeighborsClassifier(**param_grid)

    fold = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

    scores = []
    for num, (train_idx, valid_idx) in enumerate(fold.split(X, y)):
      X_train, X_test = X.iloc[train_idx], X.iloc[valid_idx]
      y_train, y_test = y.iloc[train_idx], y.iloc[valid_idx]

      model.fit(X_train, y_train)

      preds = model.predict(X_test)

      score = f1_score(y_test, preds, average='macro')

      scores.append(score)

    return np.mean(scores)

# %%
study = optuna.create_study(direction='maximize')
study.optimize(knn_objective, n_trials=100)
print('Number of finished trials:', len(study.trials))
print('Best trial:', study.best_trial.params)
print('Best trial:', study.best_value)
# Out:
# [I 2023-12-20 15:24:06,421] A new study created in memory with name: no-name-2d751e27-8ab8-4b77-8639-bc4dc033ac8a
# [I 2023-12-20 15:24:13,275] Trial 0 finished with value: 0.4790542950225326 and parameters: {'n_neighbors': 23, 'weights': 'distance', 'metric': 'manhattan', 'p': 1}. Best is trial 0 with value: 0.4790542950225326.
# [I 2023-12-20 15:24:16,294] Trial 1 finished with value: 0.4932551203263005 and parameters: {'n_neighbors': 17, 'weights': 'uniform', 'metric': 'euclidean', 'p': 4}. Best is trial 1 with value: 0.4932551203263005.
# [I 2023-12-20 15:24:18,612] Trial 2 finished with value: 0.44119185190000776 and parameters: {'n_neighbors': 48, 'weights': 'distance', 'metric': 'euclidean', 'p': 5}. Best is trial 1 with value: 0.4932551203263005.
# [I 2023-12-20 15:24:20,970] Trial 3 finished with value: 0.44119185190000776 and parameters: {'n_neighbors': 48, 'weights': 'distance', 'metric': 'euclidean', 'p': 4}. Best is trial 1 with value: 0.4932551203263005.
# [I 2023-12-20 15:24:23,809] Trial 4 finished with value: 0.4938827313142086 and parameters: {'n_neighbors': 17, 'weights': 'distance', 'metric': 'euclidean', 'p': 1}. Best is trial 4 with value: 0.4938827313142086.
# [I 2023-12-20 15:24:28,747] Trial 5 finished with value: 0.5098868665452848 and parameters: {'n_neighbors': 7, 'weights': 'uniform', 'metric': 'euclidean', 'p': 1}. Best is trial 5 with value: 0.5098868665452848.
# [I 2023-12-20 15:24:35,137] Trial 6 finished with value: 0.4632556007559905 and parameters: {'n_neighbors': 33, 'weights': 'uniform', 'metric': 'manhattan', 'p': 2}. Best is trial 5 with value: 0.5098868665452848.
# [I 2023-12-20 15:24:38,008] Trial 7 finished with value: 0.47911708417881355 and parameters: {'n_neighbors': 21, 'weights': 'uniform', 'metric': 'manhattan', 'p': 5}. Best is trial 5 with value: 0.5098868665452848.
# [I 2023-12-20 15:24:40,368] Trial 8 finished with value: 0.5183704566893359 and parameters: {'n_neighbors': 5, 'weights': 'uniform', 'metric': 'euclidean', 'p': 4}. Best is trial 8 with value: 0.5183704566893359.
# [I 2023-12-20 15:24:42,236] Trial 9 finished with value: 0.4938827313142086 and parameters: {'n_neighbors': 17, 'weights': 'distance', 'metric': 'euclidean', 'p': 1}. Best is trial 8 with value: 0.5183704566893359.
# [I 2023-12-20 15:24:45,495] Trial 10 finished with value: 0.5267570543989903 and parameters: {'n_neighbors': 1, 'weights': 'uniform', 'metric': 'manhattan', 'p': 3}. Best is trial 10 with value: 0.5267570543989903.
# [I 2023-12-20 15:24:48,337] Trial 11 finished with value: 0.5267570543989903 and parameters: {'n_neighbors': 1, 'weights': 'uniform', 'metric': 'manhattan', 'p': 3}. Best is trial 10 with value: 0.5267570543989903.
# [I 2023-12-20 15:24:51,143] Trial 12 finished with value: 0.5191810972623141 and parameters: {'n_neighbors': 3, 'weights': 'uniform', 'metric': 'manhattan', 'p': 3}. Best is trial 10 with value: 0.5267570543989903.
# [I 2023-12-20 15:24:54,606] Trial 13 finished with value: 0.509245452638971 and parameters: {'n_neighbors': 9, 'weights': 'uniform', 'metric': 'manhattan', 'p': 3}. Best is trial 10 with value: 0.5267570543989903.
# [I 2023-12-20 15:24:59,696] Trial 14 finished with value: 0.477629644491231 and parameters: {'n_neighbors': 34, 'weights': 'uniform', 'metric': 'manhattan', 'p': 2}. Best is trial 10 with value: 0.5267570543989903.
# [I 2023-12-20 15:25:02,494] Trial 15 finished with value: 0.5267570543989903 and parameters: {'n_neighbors': 1, 'weights': 'uniform', 'metric': 'manhattan', 'p': 2}. Best is trial 10 with value: 0.5267570543989903.
# [I 2023-12-20 15:25:05,310] Trial 16 finished with value: 0.509245452638971 and parameters: {'n_neighbors': 9, 'weights': 'uniform', 'metric': 'manhattan', 'p': 3}. Best is trial 10 with value: 0.5267570543989903.
# [I 2023-12-20 15:25:08,234] Trial 17 finished with value: 0.46635119848804585 and parameters: {'n_neighbors': 31, 'weights': 'uniform', 'metric': 'manhattan', 'p': 4}. Best is trial 10 with value: 0.5267570543989903.
# [I 2023-12-20 15:25:12,919] Trial 18 finished with value: 0.4954554310282619 and parameters: {'n_neighbors': 13, 'weights': 'uniform', 'metric': 'manhattan', 'p': 2}. Best is trial 10 with value: 0.5267570543989903.
# [I 2023-12-20 15:25:16,816] Trial 19 finished with value: 0.4622342090685594 and parameters: {'n_neighbors': 42, 'weights': 'uniform', 'metric': 'manhattan', 'p': 3}. Best is trial 10 with value: 0.5267570543989903.
# [I 2023-12-20 15:25:22,374] Trial 21 finished with value: 0.5267570543989903 and parameters: {'n_neighbors': 1, 'weights': 'uniform', 'metric': 'manhattan', 'p': 2}. Best is trial 10 with value: 0.5267570543989903.
# [I 2023-12-20 15:25:25,251] Trial 22 finished with value: 0.5166900999655658 and parameters: {'n_neighbors': 12, 'weights': 'uniform', 'metric': 'manhattan', 'p': 2}. Best is trial 10 with value: 0.5267570543989903.
# [I 2023-12-20 15:25:30,592] Trial 23 finished with value: 0.5193438510454904 and parameters: {'n_neighbors': 5, 'weights': 'uniform', 'metric': 'manhattan', 'p': 3}. Best is trial 10 with value: 0.5267570543989903.
# [I 2023-12-20 15:25:33,615] Trial 24 finished with value: 0.5166900999655658 and parameters: {'n_neighbors': 12, 'weights': 'uniform', 'metric': 'manhattan', 'p': 2}. Best is trial 10 with value: 0.5267570543989903.
# [I 2023-12-20 15:25:36,363] Trial 25 finished with value: 0.5267570543989903 and parameters: {'n_neighbors': 1, 'weights': 'uniform', 'metric': 'manhattan', 'p': 3}. Best is trial 10 with value: 0.5267570543989903.
# [I 2023-12-20 15:25:38,666] Trial 26 finished with value: 0.513078656368277 and parameters: {'n_neighbors': 7, 'weights': 'distance', 'metric': 'manhattan', 'p': 2}. Best is trial 10 with value: 0.5267570543989903.
# [I 2023-12-20 15:25:42,353] Trial 27 finished with value: 0.48730617920059266 and parameters: {'n_neighbors': 28, 'weights': 'uniform', 'metric': 'manhattan', 'p': 3}. Best is trial 10 with value: 0.5267570543989903.
# [I 2023-12-20 15:25:47,318] Trial 28 finished with value: 0.45387437022315735 and parameters: {'n_neighbors': 39, 'weights': 'uniform', 'metric': 'manhattan', 'p': 2}. Best is trial 10 with value: 0.5267570543989903.
# [I 2023-12-20 15:25:49,689] Trial 29 finished with value: 0.4790542950225326 and parameters: {'n_neighbors': 23, 'weights': 'distance', 'metric': 'manhattan', 'p': 1}. Best is trial 10 with value: 0.5267570543989903.
# [I 2023-12-20 15:25:52,524] Trial 30 finished with value: 0.5193438510454904 and parameters: {'n_neighbors': 5, 'weights': 'uniform', 'metric': 'manhattan', 'p': 4}. Best is trial 10 with value: 0.5267570543989903.
# [I 2023-12-20 15:25:55,292] Trial 31 finished with value: 0.5267570543989903 and parameters: {'n_neighbors': 1, 'weights': 'uniform', 'metric': 'manhattan', 'p': 4}. Best is trial 10 with value: 0.5267570543989903.
# [I 2023-12-20 15:25:59,400] Trial 32 finished with value: 0.509245452638971 and parameters: {'n_neighbors': 9, 'weights': 'uniform', 'metric': 'manhattan', 'p': 5}. Best is trial 10 with value: 0.5267570543989903.
# [I 2023-12-20 15:26:03,823] Trial 33 finished with value: 0.5153794210055571 and parameters: {'n_neighbors': 4, 'weights': 'uniform', 'metric': 'manhattan', 'p': 3}. Best is trial 10 with value: 0.5267570543989903.
# [I 2023-12-20 15:26:07,156] Trial 34 finished with value: 0.509078156010175 and parameters: {'n_neighbors': 14, 'weights': 'uniform', 'metric': 'manhattan', 'p': 4}. Best is trial 10 with value: 0.5267570543989903.
# [I 2023-12-20 15:26:07,614] Trial 35 finished with value: 0.5200005326346678 and parameters: {'n_neighbors': 1, 'weights': 'distance', 'metric': 'euclidean', 'p': 4}. Best is trial 10 with value: 0.5267570543989903.
# [I 2023-12-20 15:26:10,392] Trial 36 finished with value: 0.5142958873311883 and parameters: {'n_neighbors': 7, 'weights': 'uniform', 'metric': 'manhattan', 'p': 5}. Best is trial 10 with value: 0.5267570543989903.
# [I 2023-12-20 15:26:10,911] Trial 37 finished with value: 0.49766120603705427 and parameters: {'n_neighbors': 16, 'weights': 'distance', 'metric': 'euclidean', 'p': 4}. Best is trial 10 with value: 0.5267570543989903.
# [I 2023-12-20 15:26:14,780] Trial 38 finished with value: 0.5165178507436476 and parameters: {'n_neighbors': 10, 'weights': 'uniform', 'metric': 'manhattan', 'p': 3}. Best is trial 10 with value: 0.5267570543989903.
# [I 2023-12-20 15:26:17,474] Trial 39 finished with value: 0.5131815224508263 and parameters: {'n_neighbors': 3, 'weights': 'uniform', 'metric': 'euclidean', 'p': 3}. Best is trial 10 with value: 0.5267570543989903.
# [I 2023-12-20 15:26:20,598] Trial 40 finished with value: 0.5011518173990408 and parameters: {'n_neighbors': 20, 'weights': 'uniform', 'metric': 'manhattan', 'p': 5}. Best is trial 10 with value: 0.5267570543989903.
# [I 2023-12-20 15:26:23,437] Trial 41 finished with value: 0.5267570543989903 and parameters: {'n_neighbors': 1, 'weights': 'uniform', 'metric': 'manhattan', 'p': 2}. Best is trial 10 with value: 0.5267570543989903.
# [I 2023-12-20 15:26:26,225] Trial 42 finished with value: 0.5210045446715765 and parameters: {'n_neighbors': 6, 'weights': 'uniform', 'metric': 'manhattan', 'p': 1}. Best is trial 10 with value: 0.5267570543989903.
# [I 2023-12-20 15:26:30,537] Trial 43 finished with value: 0.5191810972623141 and parameters: {'n_neighbors': 3, 'weights': 'uniform', 'metric': 'manhattan', 'p': 2}. Best is trial 10 with value: 0.5267570543989903.
# [I 2023-12-20 15:26:35,358] Trial 44 finished with value: 0.5191810972623141 and parameters: {'n_neighbors': 3, 'weights': 'uniform', 'metric': 'manhattan', 'p': 1}. Best is trial 10 with value: 0.5267570543989903.
# [I 2023-12-20 15:26:38,143] Trial 45 finished with value: 0.5142958873311883 and parameters: {'n_neighbors': 7, 'weights': 'uniform', 'metric': 'manhattan', 'p': 2}. Best is trial 10 with value: 0.5267570543989903.
# [I 2023-12-20 15:26:38,583] Trial 46 finished with value: 0.5200005326346678 and parameters: {'n_neighbors': 1, 'weights': 'distance', 'metric': 'euclidean', 'p': 3}. Best is trial 10 with value: 0.5267570543989903.
# [I 2023-12-20 15:26:41,420] Trial 47 finished with value: 0.5005053223511128 and parameters: {'n_neighbors': 11, 'weights': 'uniform', 'metric': 'manhattan', 'p': 2}. Best is trial 10 with value: 0.5267570543989903.
# [I 2023-12-20 15:26:44,610] Trial 48 finished with value: 0.44478441740287283 and parameters: {'n_neighbors': 50, 'weights': 'uniform', 'metric': 'manhattan', 'p': 3}. Best is trial 10 with value: 0.5267570543989903.
# [I 2023-12-20 15:26:50,637] Trial 49 finished with value: 0.5153794210055571 and parameters: {'n_neighbors': 4, 'weights': 'uniform', 'metric': 'manhattan', 'p': 4}. Best is trial 10 with value: 0.5267570543989903.
# [I 2023-12-20 15:26:55,685] Trial 50 finished with value: 0.509245452638971 and parameters: {'n_neighbors': 9, 'weights': 'uniform', 'metric': 'manhattan', 'p': 3}. Best is trial 10 with value: 0.5267570543989903.
# [I 2023-12-20 15:26:58,446] Trial 51 finished with value: 0.5267570543989903 and parameters: {'n_neighbors': 1, 'weights': 'uniform', 'metric': 'manhattan', 'p': 3}. Best is trial 10 with value: 0.5267570543989903.
# [I 2023-12-20 15:27:01,896] Trial 52 finished with value: 0.5191810972623141 and parameters: {'n_neighbors': 3, 'weights': 'uniform', 'metric': 'manhattan', 'p': 3}. Best is trial 10 with value: 0.5267570543989903.
# [I 2023-12-20 15:27:07,005] Trial 53 finished with value: 0.5210045446715765 and parameters: {'n_neighbors': 6, 'weights': 'uniform', 'metric': 'manhattan', 'p': 2}. Best is trial 10 with value: 0.5267570543989903.
# [I 2023-12-20 15:27:09,801] Trial 54 finished with value: 0.5177712352015844 and parameters: {'n_neighbors': 8, 'weights': 'uniform', 'metric': 'manhattan', 'p': 3}. Best is trial 10 with value: 0.5267570543989903.
# [I 2023-12-20 15:27:12,616] Trial 55 finished with value: 0.5191810972623141 and parameters: {'n_neighbors': 3, 'weights': 'uniform', 'metric': 'manhattan', 'p': 2}. Best is trial 10 with value: 0.5267570543989903.
# [I 2023-12-20 15:27:13,625] Trial 56 finished with value: 0.5183704566893359 and parameters: {'n_neighbors': 5, 'weights': 'uniform', 'metric': 'euclidean', 'p': 4}. Best is trial 10 with value: 0.5267570543989903.
# [I 2023-12-20 15:27:15,927] Trial 57 finished with value: 0.5267570543989903 and parameters: {'n_neighbors': 1, 'weights': 'distance', 'metric': 'manhattan', 'p': 3}. Best is trial 10 with value: 0.5267570543989903.
# [I 2023-12-20 15:27:21,073] Trial 58 finished with value: 0.5193438510454904 and parameters: {'n_neighbors': 5, 'weights': 'uniform', 'metric': 'manhattan', 'p': 2}. Best is trial 10 with value: 0.5267570543989903.
# [I 2023-12-20 15:27:24,368] Trial 59 finished with value: 0.4974153549367589 and parameters: {'n_neighbors': 2, 'weights': 'uniform', 'metric': 'manhattan', 'p': 1}. Best is trial 10 with value: 0.5267570543989903.
# [I 2023-12-20 15:27:27,230] Trial 60 finished with value: 0.509078156010175 and parameters: {'n_neighbors': 14, 'weights': 'uniform', 'metric': 'manhattan', 'p': 3}. Best is trial 10 with value: 0.5267570543989903.
# [I 2023-12-20 15:27:30,053] Trial 61 finished with value: 0.5267570543989903 and parameters: {'n_neighbors': 1, 'weights': 'uniform', 'metric': 'manhattan', 'p': 4}. Best is trial 10 with value: 0.5267570543989903.
# [I 2023-12-20 15:27:33,655] Trial 62 finished with value: 0.5153794210055571 and parameters: {'n_neighbors': 4, 'weights': 'uniform', 'metric': 'manhattan', 'p': 4}. Best is trial 10 with value: 0.5267570543989903.
# [I 2023-12-20 15:27:38,564] Trial 63 finished with value: 0.5210045446715765 and parameters: {'n_neighbors': 6, 'weights': 'uniform', 'metric': 'manhattan', 'p': 4}. Best is trial 10 with value: 0.5267570543989903.
# [I 2023-12-20 15:27:41,339] Trial 64 finished with value: 0.4974153549367589 and parameters: {'n_neighbors': 2, 'weights': 'uniform', 'metric': 'manhattan', 'p': 4}. Best is trial 10 with value: 0.5267570543989903.
# [I 2023-12-20 15:27:44,139] Trial 65 finished with value: 0.5177712352015844 and parameters: {'n_neighbors': 8, 'weights': 'uniform', 'metric': 'manhattan', 'p': 5}. Best is trial 10 with value: 0.5267570543989903.
# [I 2023-12-20 15:27:46,959] Trial 66 finished with value: 0.5153794210055571 and parameters: {'n_neighbors': 4, 'weights': 'uniform', 'metric': 'manhattan', 'p': 3}. Best is trial 10 with value: 0.5267570543989903.
# [I 2023-12-20 15:27:51,836] Trial 67 finished with value: 0.4572321106408646 and parameters: {'n_neighbors': 35, 'weights': 'uniform', 'metric': 'manhattan', 'p': 2}. Best is trial 10 with value: 0.5267570543989903.
# [I 2023-12-20 15:27:53,518] Trial 68 finished with value: 0.48047015372584745 and parameters: {'n_neighbors': 26, 'weights': 'distance', 'metric': 'euclidean', 'p': 4}. Best is trial 10 with value: 0.5267570543989903.
# [I 2023-12-20 15:27:56,296] Trial 69 finished with value: 0.4974153549367589 and parameters: {'n_neighbors': 2, 'weights': 'uniform', 'metric': 'manhattan', 'p': 3}. Best is trial 10 with value: 0.5267570543989903.
# [I 2023-12-20 15:27:59,171] Trial 70 finished with value: 0.5210045446715765 and parameters: {'n_neighbors': 6, 'weights': 'uniform', 'metric': 'manhattan', 'p': 3}. Best is trial 10 with value: 0.5267570543989903.
# [I 2023-12-20 15:28:02,035] Trial 71 finished with value: 0.5267570543989903 and parameters: {'n_neighbors': 1, 'weights': 'uniform', 'metric': 'manhattan', 'p': 2}. Best is trial 10 with value: 0.5267570543989903.
# [I 2023-12-20 15:28:06,049] Trial 72 finished with value: 0.4974153549367589 and parameters: {'n_neighbors': 2, 'weights': 'uniform', 'metric': 'manhattan', 'p': 2}. Best is trial 10 with value: 0.5267570543989903.
# [I 2023-12-20 15:28:10,484] Trial 73 finished with value: 0.5193438510454904 and parameters: {'n_neighbors': 5, 'weights': 'uniform', 'metric': 'manhattan', 'p': 2}. Best is trial 10 with value: 0.5267570543989903.
# [I 2023-12-20 15:28:13,335] Trial 74 finished with value: 0.5191810972623141 and parameters: {'n_neighbors': 3, 'weights': 'uniform', 'metric': 'manhattan', 'p': 2}. Best is trial 10 with value: 0.5267570543989903.
# [I 2023-12-20 15:28:16,567] Trial 75 finished with value: 0.5267570543989903 and parameters: {'n_neighbors': 1, 'weights': 'uniform', 'metric': 'manhattan', 'p': 1}. Best is trial 10 with value: 0.5267570543989903.
# [I 2023-12-20 15:28:22,947] Trial 76 finished with value: 0.5142958873311883 and parameters: {'n_neighbors': 7, 'weights': 'uniform', 'metric': 'manhattan', 'p': 2}. Best is trial 10 with value: 0.5267570543989903.
# [I 2023-12-20 15:28:26,774] Trial 77 finished with value: 0.5153794210055571 and parameters: {'n_neighbors': 4, 'weights': 'uniform', 'metric': 'manhattan', 'p': 3}. Best is trial 10 with value: 0.5267570543989903.
# [I 2023-12-20 15:28:29,708] Trial 78 finished with value: 0.5011518173990408 and parameters: {'n_neighbors': 20, 'weights': 'uniform', 'metric': 'manhattan', 'p': 3}. Best is trial 10 with value: 0.5267570543989903.
# [I 2023-12-20 15:28:30,189] Trial 79 finished with value: 0.5095849555646147 and parameters: {'n_neighbors': 10, 'weights': 'distance', 'metric': 'euclidean', 'p': 4}. Best is trial 10 with value: 0.5267570543989903.
# [I 2023-12-20 15:28:33,023] Trial 80 finished with value: 0.4974153549367589 and parameters: {'n_neighbors': 2, 'weights': 'uniform', 'metric': 'manhattan', 'p': 2}. Best is trial 10 with value: 0.5267570543989903.
# [I 2023-12-20 15:28:36,450] Trial 81 finished with value: 0.5267570543989903 and parameters: {'n_neighbors': 1, 'weights': 'uniform', 'metric': 'manhattan', 'p': 3}. Best is trial 10 with value: 0.5267570543989903.
# [I 2023-12-20 15:28:41,427] Trial 82 finished with value: 0.5153794210055571 and parameters: {'n_neighbors': 4, 'weights': 'uniform', 'metric': 'manhattan', 'p': 3}. Best is trial 10 with value: 0.5267570543989903.
# [I 2023-12-20 15:28:44,178] Trial 83 finished with value: 0.5267570543989903 and parameters: {'n_neighbors': 1, 'weights': 'uniform', 'metric': 'manhattan', 'p': 3}. Best is trial 10 with value: 0.5267570543989903.
# [I 2023-12-20 15:28:47,026] Trial 84 finished with value: 0.5191810972623141 and parameters: {'n_neighbors': 3, 'weights': 'uniform', 'metric': 'manhattan', 'p': 3}. Best is trial 10 with value: 0.5267570543989903.
# [I 2023-12-20 15:28:49,848] Trial 85 finished with value: 0.5177712352015844 and parameters: {'n_neighbors': 8, 'weights': 'uniform', 'metric': 'manhattan', 'p': 4}. Best is trial 10 with value: 0.5267570543989903.
# [I 2023-12-20 15:28:54,562] Trial 86 finished with value: 0.5193438510454904 and parameters: {'n_neighbors': 5, 'weights': 'uniform', 'metric': 'manhattan', 'p': 5}. Best is trial 10 with value: 0.5267570543989903.
# [I 2023-12-20 15:28:58,466] Trial 87 finished with value: 0.45568041322306063 and parameters: {'n_neighbors': 46, 'weights': 'uniform', 'metric': 'manhattan', 'p': 2}. Best is trial 10 with value: 0.5267570543989903.
# [I 2023-12-20 15:29:01,258] Trial 88 finished with value: 0.4974153549367589 and parameters: {'n_neighbors': 2, 'weights': 'uniform', 'metric': 'manhattan', 'p': 3}. Best is trial 10 with value: 0.5267570543989903.
# [I 2023-12-20 15:29:04,056] Trial 89 finished with value: 0.5210045446715765 and parameters: {'n_neighbors': 6, 'weights': 'uniform', 'metric': 'manhattan', 'p': 3}. Best is trial 10 with value: 0.5267570543989903.
# [I 2023-12-20 15:29:07,064] Trial 90 finished with value: 0.5153794210055571 and parameters: {'n_neighbors': 4, 'weights': 'uniform', 'metric': 'manhattan', 'p': 2}. Best is trial 10 with value: 0.5267570543989903.
# [I 2023-12-20 15:29:11,869] Trial 91 finished with value: 0.5267570543989903 and parameters: {'n_neighbors': 1, 'weights': 'distance', 'metric': 'manhattan', 'p': 3}. Best is trial 10 with value: 0.5267570543989903.
# [I 2023-12-20 15:29:16,793] Trial 92 finished with value: 0.5267570543989903 and parameters: {'n_neighbors': 2, 'weights': 'distance', 'metric': 'manhattan', 'p': 3}. Best is trial 10 with value: 0.5267570543989903.
# [I 2023-12-20 15:29:20,766] Trial 93 finished with value: 0.5267570543989903 and parameters: {'n_neighbors': 1, 'weights': 'distance', 'metric': 'manhattan', 'p': 3}. Best is trial 10 with value: 0.5267570543989903.
# [I 2023-12-20 15:29:23,642] Trial 94 finished with value: 0.5198897057043096 and parameters: {'n_neighbors': 3, 'weights': 'distance', 'metric': 'manhattan', 'p': 3}. Best is trial 10 with value: 0.5267570543989903.
# [I 2023-12-20 15:29:28,207] Trial 95 finished with value: 0.5267570543989903 and parameters: {'n_neighbors': 2, 'weights': 'distance', 'metric': 'manhattan', 'p': 4}. Best is trial 10 with value: 0.5267570543989903.
# [I 2023-12-20 15:29:28,862] Trial 96 finished with value: 0.5211423274127808 and parameters: {'n_neighbors': 4, 'weights': 'distance', 'metric': 'euclidean', 'p': 3}. Best is trial 10 with value: 0.5267570543989903.
# [I 2023-12-20 15:29:31,669] Trial 97 finished with value: 0.5210045446715765 and parameters: {'n_neighbors': 6, 'weights': 'uniform', 'metric': 'manhattan', 'p': 2}. Best is trial 10 with value: 0.5267570543989903.
# [I 2023-12-20 15:29:34,416] Trial 98 finished with value: 0.5267570543989903 and parameters: {'n_neighbors': 1, 'weights': 'uniform', 'metric': 'manhattan', 'p': 3}. Best is trial 10 with value: 0.5267570543989903.
# [I 2023-12-20 15:29:37,210] Trial 99 finished with value: 0.5193438510454904 and parameters: {'n_neighbors': 5, 'weights': 'uniform', 'metric': 'manhattan', 'p': 4}. Best is trial 10 with value: 0.5267570543989903.
# Number of finished trials: 100
# Best trial: {'n_neighbors': 1, 'weights': 'uniform', 'metric': 'manhattan', 'p': 3}
# Best trial: 0.5267570543989903

# %%
# shuffle = True로 했기 때문에 하이퍼파라미터 값은 계속해서 변경 됨 --> 최상의 값 : 0.5267570543989903

# %%
# 해당 코드의 파라미터 값이 위 코드 최상의 파라미터값과 다른 이유는 같은 점수값의 모델이 다수이기 때문입니다.
knn_params = {
 'n_neighbors': 1, 'weights': 'distance', 'metric': 'manhattan', 'p': 5
}
knn = KNeighborsClassifier(
  **knn_params
)
knn.fit(X, y)
# Out:
# KNeighborsClassifier(metric='manhattan', n_neighbors=1, p=5, weights='distance')

# %% [markdown]
# # Post Precessing

# %%
final_test = knn.predict(test[X.columns])
test['target'] = final_test
test['target'].value_counts()
# Out:
# 1    6105
# 0    3895
# Name: target, dtype: int64

# %%
ss['target']= final_test
print(ss['target'].value_counts())
path = "./20231208_knn1.csv"
ss.to_csv(path,index=False)
# Out:
# 1    6105
# 0    3895
# Name: target, dtype: int64
